# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("books_dataset.csv")

# %%
df.shape
# Out:
# (20, 4)

# %%
df.describe()
# Out:
#                        Title    Price Availability Rating
# count                     20       20           20     20
# unique                    20       20            1      5
# top     A Light in the Attic  Â£51.77     In stock    One
# freq                       1        1           20      6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         20 non-null     object
#  1   Price         20 non-null     object
#  2   Availability  20 non-null     object
#  3   Rating        20 non-null     object
# dtypes: object(4)
# memory usage: 772.0+ bytes

# %%
df.columns
# Out:
# Index(['Title', 'Price', 'Availability', 'Rating'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Title           0
# Price           0
# Availability    0
# Rating          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Ensure 'Price' column is numeric for plotting
# This check makes the cell more robust, in case the column type changes upstream.
if not pd.api.types.is_numeric_dtype(df['Price']):
    df['Price'] = df['Price'].astype(str).str.replace('Â£', '').astype(float)

plt.figure(figsize=(8, 5))

plt.hist(df['Price'], bins=10, edgecolor='black')

plt.xlabel("Book Price (£)", fontsize=11)
plt.ylabel("Number of Books", fontsize=11)
plt.title("Distribution of Book Prices", fontsize=13)

plt.grid(axis='y', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))

plt.hist(df['Rating'], bins=range(1, 7), align='left', edgecolor='black')

plt.xticks([1, 2, 3, 4, 5])
plt.xlabel("Rating (Stars)", fontsize=11)
plt.ylabel("Number of Books", fontsize=11)
plt.title("Distribution of Book Ratings", fontsize=13)

plt.grid(axis='y', alpha=0.4)
plt.tight_layout()
plt.show()

# %%
df['Availability'].value_counts()
# Out:
# Availability
# In stock    20
# Name: count, dtype: int64

# %%
df['Availability'].value_counts().plot(kind='bar')
plt.title("Availability Status")
plt.show()

# %%
plt.scatter(df['Rating'], df['Price'])
plt.xlabel("Rating")
plt.ylabel("Price")
plt.title("Price vs Rating")
plt.show()

# %%
df['Price'] = df['Price'].str.replace('Â£', '').astype(float)
plt.boxplot(df['Price'])
plt.title("Price Outliers")
plt.show()
