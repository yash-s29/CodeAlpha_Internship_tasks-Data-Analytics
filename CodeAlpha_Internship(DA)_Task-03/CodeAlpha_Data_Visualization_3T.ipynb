# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('books_dataset.csv')

# %%
sns.set(style="whitegrid")

# %%
# The 'Price' column appears to be already numeric, so no cleaning is needed.
# If you encounter string values with 'Â£' in future runs, you might need to re-evaluate the data loading or cleaning step.

#are book prices concentrated or widely spread?
#Histogram + KDE
plt.figure(figsize=(7, 5))
sns.histplot(df['Price'], bins=10, kde=True)
plt.xlabel("Book Price (£)")
plt.ylabel("Number of Books")
plt.title("Distribution of Book Prices")
plt.tight_layout()
plt.show()

# %%
#How are books rated overall?
#Count Plot (Correct for Discrete Data)
plt.figure(figsize=(7, 5))
sns.countplot(x='Rating', data=df, hue='Rating', palette='viridis', legend=False)
plt.xlabel("Rating (Stars)")
plt.ylabel("Number of Books")
plt.title("Distribution of Book Ratings")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(x='Rating', y='Price', data=df, color = 'black')
plt.xlabel("Rating (Stars)")
plt.ylabel("Book Price (£)")
plt.title("Relationship Between Book Rating and Price")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(x='Rating', y='Price', data=df, color = 'cyan')
plt.xlabel("Rating (Stars)")
plt.ylabel("Book Price (£)")
plt.title("Price Distribution Across Ratings")
plt.tight_layout()
plt.show()
